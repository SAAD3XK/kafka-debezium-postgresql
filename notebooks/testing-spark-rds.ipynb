# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import from_json, col
from pyspark.sql.types import StringType, DoubleType, StructType, BooleanType, ArrayType, IntegerType
import os
import logging

# %%
KAFKA_TOPIC_NAME_CONS = os.environ.get('INPUT_TOPIC')
KAFKA_OUTPUT_TOPIC_NAME_CONS = os.environ.get('OUTPUT_TOPIC')
KAFKA_BOOTSTRAP_SERVERS_CONS = os.environ.get('KAFKA_BOOTSTRAP_SERVERS')

logging.basicConfig(level=logging.INFO)

# %%
spark = SparkSession \
        .builder \
        .appName("PySpark Structured Streaming with Kafka Demo") \
        .master("local[*]") \
        .config("spark.jars.packages", "org.apache.spark:spark-sql-kafka-0-10_2.12:3.4.0") \
        .getOrCreate()

spark.sparkContext.setLogLevel("INFO")

schema = StructType().add("id", IntegerType()) \
                     .add("license_no", StringType()) \
                     .add("status", StringType()) \
                     .add("is_detected", BooleanType()) \
                     .add("detected_timestamp", ArrayType(IntegerType())) \
                     .add("detected_frame", ArrayType(StringType()))
stock_df = spark \
        .readStream \
        .format("kafka") \
        .option("kafka.bootstrap.servers", KAFKA_BOOTSTRAP_SERVERS_CONS) \
        .option("subscribe", KAFKA_TOPIC_NAME_CONS) \
        .option("startingOffsets", "earliest") \
        .load()

# %%
stock_df1 = stock_df.selectExpr("CAST(value AS STRING)", "timestamp")

# %%
stock_df2 = stock_df1\
        .select(from_json(col("value"), schema).alias("value_columns"), "timestamp")

# selecting all columns in the "value_columns" column
stock_df3 = stock_df2.select("value_columns.*", "timestamp")

# %%
stock_df3.dtypes

# %% [markdown]
# ## Writing final dataframe to the output topic

# %%
current_directory = os.getcwd()

# Set the checkpoint location to the current directory
checkpoint_location = os.path.join(current_directory, "checkpoint")

# %%
stock_write_stream = stock_df1.selectExpr("to_json(struct(*)) AS value") \
                              .writeStream \
                              .format("kafka") \
                              .option("kafka.bootstrap.servers", KAFKA_BOOTSTRAP_SERVERS_CONS) \
                              .option("topic", KAFKA_OUTPUT_TOPIC_NAME_CONS) \
                              .trigger(processingTime='1 seconds') \
                              .outputMode("update") \
                              .option("checkpointLocation", checkpoint_location) \
                              .start()

stock_write_stream.awaitTermination()
# Out:
# 24/03/14 09:33:05 INFO ResolveWriteToStream: Checkpoint root /app/checkpoint resolved to file:/app/checkpoint.
# 24/03/14 09:33:05 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# 24/03/14 09:33:05 INFO MicroBatchExecution: Starting [id = fecb0560-68f2-42df-9c50-32c870e251ce, runId = 34e3138d-a1e4-4da7-bddd-a12597b03fd5]. Use file:/app/checkpoint to store the query checkpoint.
# 24/03/14 09:33:05 INFO MicroBatchExecution: Reading table [org.apache.spark.sql.kafka010.KafkaSourceProvider$KafkaTable@6500554e] from DataSourceV2 named 'kafka' [org.apache.spark.sql.kafka010.KafkaSourceProvider@6bc7a646]
# 24/03/14 09:33:05 INFO OffsetSeqLog: BatchIds found from listing:
# 24/03/14 09:33:05 INFO OffsetSeqLog: BatchIds found from listing:
# 24/03/14 09:33:05 INFO MicroBatchExecution: Starting new streaming query.
# 24/03/14 09:33:05 INFO MicroBatchExecution: Stream started from {}
# 24/03/14 09:33:05 INFO AdminClientConfig: AdminClientConfig values:
# 	bootstrap.servers = [kafka:9092]
# 	client.dns.lookup = use_all_dns_ips
# 	client.id =
# 	connections.max.idle.ms = 300000
# 	default.api.timeout.ms = 60000
# 	metadata.max.age.ms = 300000
# 	metric.reporters = []
# 	metrics.num.samples = 2
# 	metrics.recording.level = INFO
# 	metrics.sample.window.ms = 30000
# 	receive.buffer.bytes = 65536
# 	reconnect.backoff.max.ms = 1000
# 	reconnect.backoff.ms = 50
# 	request.timeout.ms = 30000
# 	retries = 2147483647
# 	retry.backoff.ms = 100
# 	sasl.client.callback.handler.class = null
# 	sasl.jaas.config = null
# 	sasl.kerberos.kinit.cmd = /usr/bin/kinit
# 	sasl.kerberos.min.time.before.relogin = 60000
# 	sasl.kerberos.service.name = null
# 	sasl.kerberos.ticket.renew.jitter = 0.05
# 	sasl.kerberos.ticket.renew.window.factor = 0.8
# 	sasl.login.callback.handler.class = null
# 	sasl.login.class = null
# 	sasl.login.connect.timeout.ms = null
# 	sasl.login.read.timeout.ms = null
# 	sasl.login.refresh.buffer.seconds = 300
# 	sasl.login.refresh.min.period.seconds = 60
# 	sasl.login.refresh.window.factor = 0.8
# 	sasl.login.refresh.window.jitter = 0.05
# 	sasl.login.retry.backoff.max.ms = 10000
# 	sasl.login.retry.backoff.ms = 100
# 	sasl.mechanism = GSSAPI
# 	sasl.oauthbearer.clock.skew.seconds = 30
# 	sasl.oauthbearer.expected.audience = null
# 	sasl.oauthbearer.expected.issuer = null
# 	sasl.oauthbearer.jwks.endpoint.refresh.ms = 3600000
# 	sasl.oauthbearer.jwks.endpoint.retry.backoff.max.ms = 10000
# 	sasl.oauthbearer.jwks.endpoint.retry.backoff.ms = 100
# 	sasl.oauthbearer.jwks.endpoint.url = null
# 	sasl.oauthbearer.scope.claim.name = scope
# 	sasl.oauthbearer.sub.claim.name = sub
# 	sasl.oauthbearer.token.endpoint.url = null
# 	security.protocol = PLAINTEXT
# 	security.providers = null
# 	send.buffer.bytes = 131072
# 	socket.connection.setup.timeout.max.ms = 30000
# 	socket.connection.setup.timeout.ms = 10000
# 	ssl.cipher.suites = null
# 	ssl.enabled.protocols = [TLSv1.2, TLSv1.3]
# 	ssl.endpoint.identification.algorithm = https
# 	ssl.engine.factory.class = null
# 	ssl.key.password = null
# 	ssl.keymanager.algorithm = SunX509
# 	ssl.keystore.certificate.chain = null
# 	ssl.keystore.key = null
# 	ssl.keystore.location = null
# 	ssl.keystore.password = null
# 	ssl.keystore.type = JKS
# 	ssl.protocol = TLSv1.3
# 	ssl.provider = null
# 	ssl.secure.random.implementation = null
# 	ssl.trustmanager.algorithm = PKIX
# 	ssl.truststore.certificates = null
# 	ssl.truststore.location = null
# 	ssl.truststore.password = null
# 	ssl.truststore.type = JKS
#
# 24/03/14 09:33:05 WARN AdminClientConfig: These configurations '[key.deserializer, value.deserializer, enable.auto.commit, max.poll.records, auto.offset.reset]' were supplied but are not used yet.
# 24/03/14 09:33:05 INFO AppInfoParser: Kafka version: 3.3.2
# 24/03/14 09:33:05 INFO AppInfoParser: Kafka commitId: b66af662e61082cb
# 24/03/14 09:33:05 INFO AppInfoParser: Kafka startTimeMs: 1710408785779
# 24/03/14 09:33:05 INFO CheckpointFileManager: Writing atomically to file:/app/checkpoint/sources/0/0 using temp file file:/app/checkpoint/sources/0/.0.c82c63b0-3b96-4237-b351-8d9704f076ac.tmp
# 24/03/14 09:33:05 INFO CheckpointFileManager: Renamed temp file file:/app/checkpoint/sources/0/.0.c82c63b0-3b96-4237-b351-8d9704f076ac.tmp to file:/app/checkpoint/sources/0/0
# 24/03/14 09:33:05 INFO KafkaMicroBatchStream: Initial offsets: {"rds_first_topic":{"0":0}}
# 24/03/14 09:33:05 INFO CheckpointFileManager: Writing atomically to file:/app/checkpoint/offsets/0 using temp file file:/app/checkpoint/offsets/.0.a9fa08d5-89fa-4795-85da-f83d49727fca.tmp
# 24/03/14 09:33:05 INFO CheckpointFileManager: Renamed temp file file:/app/checkpoint/offsets/.0.a9fa08d5-89fa-4795-85da-f83d49727fca.tmp to file:/app/checkpoint/offsets/0
# 24/03/14 09:33:05 INFO MicroBatchExecution: Committed offsets for batch 0. Metadata OffsetSeqMetadata(0,1710408785834,Map(spark.sql.streaming.stateStore.providerClass -> org.apache.spark.sql.execution.streaming.state.HDFSBackedStateStoreProvider, spark.sql.streaming.join.stateFormatVersion -> 2, spark.sql.streaming.stateStore.compression.codec -> lz4, spark.sql.streaming.stateStore.rocksdb.formatVersion -> 5, spark.sql.streaming.statefulOperator.useStrictDistribution -> true, spark.sql.streaming.flatMapGroupsWithState.stateFormatVersion -> 2, spark.sql.streaming.multipleWatermarkPolicy -> min, spark.sql.streaming.aggregation.stateFormatVersion -> 2, spark.sql.shuffle.partitions -> 200))
# 24/03/14 09:33:05 INFO KafkaOffsetReaderAdmin: Partitions added: Map()
# 24/03/14 09:33:05 INFO KafkaOffsetReaderAdmin: Partitions added: Map()
# 24/03/14 09:33:05 INFO KafkaOffsetReaderAdmin: Partitions added: Map()
# 24/03/14 09:33:05 INFO KafkaOffsetReaderAdmin: Partitions added: Map()
# 24/03/14 09:33:05 INFO KafkaOffsetReaderAdmin: Partitions added: Map()
# 24/03/14 09:33:05 INFO KafkaOffsetReaderAdmin: Partitions added: Map()
# 24/03/14 09:33:06 INFO WriteToDataSourceV2Exec: Start processing data source write support: MicroBatchWrite[epoch: 0, writer: org.apache.spark.sql.kafka010.KafkaStreamingWrite@59cfa549]. The input RDD has 1 partitions.
# 24/03/14 09:33:06 INFO SparkContext: Starting job: start at NativeMethodAccessorImpl.java:0
# 24/03/14 09:33:06 INFO DAGScheduler: Got job 0 (start at NativeMethodAccessorImpl.java:0) with 1 output partitions
# 24/03/14 09:33:06 INFO DAGScheduler: Final stage: ResultStage 0 (start at NativeMethodAccessorImpl.java:0)
# 24/03/14 09:33:06 INFO DAGScheduler: Parents of final stage: List()
# 24/03/14 09:33:06 INFO DAGScheduler: Missing parents: List()
# 24/03/14 09:33:06 INFO DAGScheduler: Submitting ResultStage 0 (MapPartitionsRDD[2] at start at NativeMethodAccessorImpl.java:0), which has no missing parents
# 24/03/14 09:33:06 INFO MemoryStore: Block broadcast_0 stored as values in memory (estimated size 20.0 KiB, free 434.4 MiB)
# 24/03/14 09:33:06 INFO MemoryStore: Block broadcast_0_piece0 stored as bytes in memory (estimated size 9.9 KiB, free 434.4 MiB)
# 24/03/14 09:33:06 INFO BlockManagerInfo: Added broadcast_0_piece0 in memory on 3d109c760830:39923 (size: 9.9 KiB, free: 434.4 MiB)
# 24/03/14 09:33:06 INFO SparkContext: Created broadcast 0 from broadcast at DAGScheduler.scala:1535
# 24/03/14 09:33:06 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 0 (MapPartitionsRDD[2] at start at NativeMethodAccessorImpl.java:0) (first 15 tasks are for partitions Vector(0))
# 24/03/14 09:33:06 INFO TaskSchedulerImpl: Adding task set 0.0 with 1 tasks resource profile 0
# 24/03/14 09:33:06 INFO TaskSetManager: Starting task 0.0 in stage 0.0 (TID 0) (3d109c760830, executor driver, partition 0, PROCESS_LOCAL, 8307 bytes)
# 24/03/14 09:33:06 INFO Executor: Running task 0.0 in stage 0.0 (TID 0)
# 24/03/14 09:33:06 INFO CodeGenerator: Code generated in 150.827398 ms
# 24/03/14 09:33:06 INFO CodeGenerator: Code generated in 19.372332 ms
# 24/03/14 09:33:06 INFO CodeGenerator: Code generated in 14.419214 ms
# 24/03/14 09:33:06 INFO CodeGenerator: Code generated in 17.719644 ms
# 24/03/14 09:33:06 INFO ConsumerConfig: ConsumerConfig values:
# 	allow.auto.create.topics = true
# 	auto.commit.interval.ms = 5000
# 	auto.offset.reset = none
# 	bootstrap.servers = [kafka:9092]
# 	check.crcs = true
# 	client.dns.lookup = use_all_dns_ips
# 	client.id = consumer-spark-kafka-source-fdb4650d-e10a-400c-a1c3-dc9d97452691--1378282063-executor-1
# 	client.rack =
# 	connections.max.idle.ms = 540000
# 	default.api.timeout.ms = 60000
# 	enable.auto.commit = false
# 	exclude.internal.topics = true
# 	fetch.max.bytes = 52428800
# 	fetch.max.wait.ms = 500
# 	fetch.min.bytes = 1
# 	group.id = spark-kafka-source-fdb4650d-e10a-400c-a1c3-dc9d97452691--1378282063-executor
# 	group.instance.id = null
# 	heartbeat.interval.ms = 3000
# 	interceptor.classes = []
# 	internal.leave.group.on.close = true
# 	internal.throw.on.fetch.stable.offset.unsupported = false
# 	isolation.level = read_uncommitted
# 	key.deserializer = class org.apache.kafka.common.serialization.ByteArrayDeserializer
# 	max.partition.fetch.bytes = 1048576
# 	max.poll.interval.ms = 300000
# 	max.poll.records = 500
# 	metadata.max.age.ms = 300000
# 	metric.reporters = []
# 	metrics.num.samples = 2
# 	metrics.recording.level = INFO
# 	metrics.sample.window.ms = 30000
# 	partition.assignment.strategy = [class org.apache.kafka.clients.consumer.RangeAssignor, class org.apache.kafka.clients.consumer.CooperativeStickyAssignor]
# 	receive.buffer.bytes = 65536
# 	reconnect.backoff.max.ms = 1000
# 	reconnect.backoff.ms = 50
# 	request.timeout.ms = 30000
# 	retry.backoff.ms = 100
# 	sasl.client.callback.handler.class = null
# 	sasl.jaas.config = null
# 	sasl.kerberos.kinit.cmd = /usr/bin/kinit
# 	sasl.kerberos.min.time.before.relogin = 60000
# 	sasl.kerberos.service.name = null
# 	sasl.kerberos.ticket.renew.jitter = 0.05
# 	sasl.kerberos.ticket.renew.window.factor = 0.8
# 	sasl.login.callback.handler.class = null
# 	sasl.login.class = null
# 	sasl.login.connect.timeout.ms = null
# 	sasl.login.read.timeout.ms = null
# 	sasl.login.refresh.buffer.seconds = 300
# 	sasl.login.refresh.min.period.seconds = 60
# 	sasl.login.refresh.window.factor = 0.8
# 	sasl.login.refresh.window.jitter = 0.05
# 	sasl.login.retry.backoff.max.ms = 10000
# 	sasl.login.retry.backoff.ms = 100
# 	sasl.mechanism = GSSAPI
# 	sasl.oauthbearer.clock.skew.seconds = 30
# 	sasl.oauthbearer.expected.audience = null
# 	sasl.oauthbearer.expected.issuer = null
# 	sasl.oauthbearer.jwks.endpoint.refresh.ms = 3600000
# 	sasl.oauthbearer.jwks.endpoint.retry.backoff.max.ms = 10000
# 	sasl.oauthbearer.jwks.endpoint.retry.backoff.ms = 100
# 	sasl.oauthbearer.jwks.endpoint.url = null
# 	sasl.oauthbearer.scope.claim.name = scope
# 	sasl.oauthbearer.sub.claim.name = sub
# 	sasl.oauthbearer.token.endpoint.url = null
# 	security.protocol = PLAINTEXT
# 	security.providers = null
# 	send.buffer.bytes = 131072
# 	session.timeout.ms = 45000
# 	socket.connection.setup.timeout.max.ms = 30000
# 	socket.connection.setup.timeout.ms = 10000
# 	ssl.cipher.suites = null
# 	ssl.enabled.protocols = [TLSv1.2, TLSv1.3]
# 	ssl.endpoint.identification.algorithm = https
# 	ssl.engine.factory.class = null
# 	ssl.key.password = null
# 	ssl.keymanager.algorithm = SunX509
# 	ssl.keystore.certificate.chain = null
# 	ssl.keystore.key = null
# 	ssl.keystore.location = null
# 	ssl.keystore.password = null
# 	ssl.keystore.type = JKS
# 	ssl.protocol = TLSv1.3
# 	ssl.provider = null
# 	ssl.secure.random.implementation = null
# 	ssl.trustmanager.algorithm = PKIX
# 	ssl.truststore.certificates = null
# 	ssl.truststore.location = null
# 	ssl.truststore.password = null
# 	ssl.truststore.type = JKS
# 	value.deserializer = class org.apache.kafka.common.serialization.ByteArrayDeserializer
#
# 24/03/14 09:33:06 INFO AppInfoParser: Kafka version: 3.3.2
# 24/03/14 09:33:06 INFO AppInfoParser: Kafka commitId: b66af662e61082cb
# 24/03/14 09:33:06 INFO AppInfoParser: Kafka startTimeMs: 1710408786686
# 24/03/14 09:33:06 INFO KafkaConsumer: [Consumer clientId=consumer-spark-kafka-source-fdb4650d-e10a-400c-a1c3-dc9d97452691--1378282063-executor-1, groupId=spark-kafka-source-fdb4650d-e10a-400c-a1c3-dc9d97452691--1378282063-executor] Assigned to partition(s): rds_first_topic-0
# 24/03/14 09:33:06 INFO KafkaConsumer: [Consumer clientId=consumer-spark-kafka-source-fdb4650d-e10a-400c-a1c3-dc9d97452691--1378282063-executor-1, groupId=spark-kafka-source-fdb4650d-e10a-400c-a1c3-dc9d97452691--1378282063-executor] Seeking to offset 0 for partition rds_first_topic-0
# 24/03/14 09:33:06 INFO Metadata: [Consumer clientId=consumer-spark-kafka-source-fdb4650d-e10a-400c-a1c3-dc9d97452691--1378282063-executor-1, groupId=spark-kafka-source-fdb4650d-e10a-400c-a1c3-dc9d97452691--1378282063-executor] Resetting the last seen epoch of partition rds_first_topic-0 to 0 since the associated topicId changed from null to Z4XOFIqoTnSTzSJpx9-aIw
# 24/03/14 09:33:06 INFO Metadata: [Consumer clientId=consumer-spark-kafka-source-fdb4650d-e10a-400c-a1c3-dc9d97452691--1378282063-executor-1, groupId=spark-kafka-source-fdb4650d-e10a-400c-a1c3-dc9d97452691--1378282063-executor] Cluster ID: Xyl80J86RTerua6HHr7L2Q
# 24/03/14 09:33:06 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-fdb4650d-e10a-400c-a1c3-dc9d97452691--1378282063-executor-1, groupId=spark-kafka-source-fdb4650d-e10a-400c-a1c3-dc9d97452691--1378282063-executor] Seeking to earliest offset of partition rds_first_topic-0
# 24/03/14 09:33:07 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-fdb4650d-e10a-400c-a1c3-dc9d97452691--1378282063-executor-1, groupId=spark-kafka-source-fdb4650d-e10a-400c-a1c3-dc9d97452691--1378282063-executor] Resetting offset for partition rds_first_topic-0 to position FetchPosition{offset=0, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[kafka:9092 (id: 1 rack: null)], epoch=0}}.
# 24/03/14 09:33:07 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-fdb4650d-e10a-400c-a1c3-dc9d97452691--1378282063-executor-1, groupId=spark-kafka-source-fdb4650d-e10a-400c-a1c3-dc9d97452691--1378282063-executor] Seeking to latest offset of partition rds_first_topic-0
# 24/03/14 09:33:07 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-fdb4650d-e10a-400c-a1c3-dc9d97452691--1378282063-executor-1, groupId=spark-kafka-source-fdb4650d-e10a-400c-a1c3-dc9d97452691--1378282063-executor] Resetting offset for partition rds_first_topic-0 to position FetchPosition{offset=8, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[kafka:9092 (id: 1 rack: null)], epoch=0}}.
# 24/03/14 09:33:07 INFO ProducerConfig: ProducerConfig values:
# 	acks = -1
# 	batch.size = 16384
# 	bootstrap.servers = [kafka:9092]
# 	buffer.memory = 33554432
# 	client.dns.lookup = use_all_dns_ips
# 	client.id = producer-1
# 	compression.type = none
# 	connections.max.idle.ms = 540000
# 	delivery.timeout.ms = 120000
# 	enable.idempotence = true
# 	interceptor.classes = []
# 	key.serializer = class org.apache.kafka.common.serialization.ByteArraySerializer
# 	linger.ms = 0
# 	max.block.ms = 60000
# 	max.in.flight.requests.per.connection = 5
# 	max.request.size = 1048576
# 	metadata.max.age.ms = 300000
# 	metadata.max.idle.ms = 300000
# 	metric.reporters = []
# 	metrics.num.samples = 2
# 	metrics.recording.level = INFO
# 	metrics.sample.window.ms = 30000
# 	partitioner.adaptive.partitioning.enable = true
# 	partitioner.availability.timeout.ms = 0
# 	partitioner.class = null
# 	partitioner.ignore.keys = false
# 	receive.buffer.bytes = 32768
# 	reconnect.backoff.max.ms = 1000
# 	reconnect.backoff.ms = 50
# 	request.timeout.ms = 30000
# 	retries = 2147483647
# 	retry.backoff.ms = 100
# 	sasl.client.callback.handler.class = null
# 	sasl.jaas.config = null
# 	sasl.kerberos.kinit.cmd = /usr/bin/kinit
# 	sasl.kerberos.min.time.before.relogin = 60000
# 	sasl.kerberos.service.name = null
# 	sasl.kerberos.ticket.renew.jitter = 0.05
# 	sasl.kerberos.ticket.renew.window.factor = 0.8
# 	sasl.login.callback.handler.class = null
# 	sasl.login.class = null
# 	sasl.login.connect.timeout.ms = null
# 	sasl.login.read.timeout.ms = null
# 	sasl.login.refresh.buffer.seconds = 300
# 	sasl.login.refresh.min.period.seconds = 60
# 	sasl.login.refresh.window.factor = 0.8
# 	sasl.login.refresh.window.jitter = 0.05
# 	sasl.login.retry.backoff.max.ms = 10000
# 	sasl.login.retry.backoff.ms = 100
# 	sasl.mechanism = GSSAPI
# 	sasl.oauthbearer.clock.skew.seconds = 30
# 	sasl.oauthbearer.expected.audience = null
# 	sasl.oauthbearer.expected.issuer = null
# 	sasl.oauthbearer.jwks.endpoint.refresh.ms = 3600000
# 	sasl.oauthbearer.jwks.endpoint.retry.backoff.max.ms = 10000
# 	sasl.oauthbearer.jwks.endpoint.retry.backoff.ms = 100
# 	sasl.oauthbearer.jwks.endpoint.url = null
# 	sasl.oauthbearer.scope.claim.name = scope
# 	sasl.oauthbearer.sub.claim.name = sub
# 	sasl.oauthbearer.token.endpoint.url = null
# 	security.protocol = PLAINTEXT
# 	security.providers = null
# 	send.buffer.bytes = 131072
# 	socket.connection.setup.timeout.max.ms = 30000
# 	socket.connection.setup.timeout.ms = 10000
# 	ssl.cipher.suites = null
# 	ssl.enabled.protocols = [TLSv1.2, TLSv1.3]
# 	ssl.endpoint.identification.algorithm = https
# 	ssl.engine.factory.class = null
# 	ssl.key.password = null
# 	ssl.keymanager.algorithm = SunX509
# 	ssl.keystore.certificate.chain = null
# 	ssl.keystore.key = null
# 	ssl.keystore.location = null
# 	ssl.keystore.password = null
# 	ssl.keystore.type = JKS
# 	ssl.protocol = TLSv1.3
# 	ssl.provider = null
# 	ssl.secure.random.implementation = null
# 	ssl.trustmanager.algorithm = PKIX
# 	ssl.truststore.certificates = null
# 	ssl.truststore.location = null
# 	ssl.truststore.password = null
# 	ssl.truststore.type = JKS
# 	transaction.timeout.ms = 60000
# 	transactional.id = null
# 	value.serializer = class org.apache.kafka.common.serialization.ByteArraySerializer
#
# 24/03/14 09:33:07 INFO KafkaProducer: [Producer clientId=producer-1] Instantiated an idempotent producer.
# 24/03/14 09:33:07 INFO AppInfoParser: Kafka version: 3.3.2
# 24/03/14 09:33:07 INFO AppInfoParser: Kafka commitId: b66af662e61082cb
# 24/03/14 09:33:07 INFO AppInfoParser: Kafka startTimeMs: 1710408787360
# 24/03/14 09:33:07 WARN NetworkClient: [Producer clientId=producer-1] Error while fetching metadata with correlation id 1 : {output_topic_sink=LEADER_NOT_AVAILABLE}
# 24/03/14 09:33:07 INFO Metadata: [Producer clientId=producer-1] Cluster ID: Xyl80J86RTerua6HHr7L2Q
# 24/03/14 09:33:07 INFO TransactionManager: [Producer clientId=producer-1] ProducerId set to 0 with epoch 0
# 24/03/14 09:33:07 INFO Metadata: [Producer clientId=producer-1] Resetting the last seen epoch of partition output_topic_sink-0 to 0 since the associated topicId changed from null to kU1RCv-_SjusjtdruOkI3g
# 24/03/14 09:33:07 INFO DataWritingSparkTask: Commit authorized for partition 0 (task 0, attempt 0, stage 0.0)
# 24/03/14 09:33:07 INFO DataWritingSparkTask: Committed partition 0 (task 0, attempt 0, stage 0.0)
# 24/03/14 09:33:07 INFO Executor: Finished task 0.0 in stage 0.0 (TID 0). 1776 bytes result sent to driver
# 24/03/14 09:33:07 INFO TaskSetManager: Finished task 0.0 in stage 0.0 (TID 0) in 1306 ms on 3d109c760830 (executor driver) (1/1)
# 24/03/14 09:33:07 INFO TaskSchedulerImpl: Removed TaskSet 0.0, whose tasks have all completed, from pool
# 24/03/14 09:33:07 INFO DAGScheduler: ResultStage 0 (start at NativeMethodAccessorImpl.java:0) finished in 1.506 s
# 24/03/14 09:33:07 INFO DAGScheduler: Job 0 is finished. Cancelling potential speculative or zombie tasks for this job
# 24/03/14 09:33:07 INFO TaskSchedulerImpl: Killing all running tasks in stage 0: Stage finished
# 24/03/14 09:33:07 INFO DAGScheduler: Job 0 finished: start at NativeMethodAccessorImpl.java:0, took 1.533078 s
# 24/03/14 09:33:07 INFO WriteToDataSourceV2Exec: Data source write support MicroBatchWrite[epoch: 0, writer: org.apache.spark.sql.kafka010.KafkaStreamingWrite@59cfa549] is committing.
# 24/03/14 09:33:07 INFO WriteToDataSourceV2Exec: Data source write support MicroBatchWrite[epoch: 0, writer: org.apache.spark.sql.kafka010.KafkaStreamingWrite@59cfa549] committed.
# 24/03/14 09:33:07 INFO CheckpointFileManager: Writing atomically to file:/app/checkpoint/commits/0 using temp file file:/app/checkpoint/commits/.0.5219c10f-3b79-4fd8-9185-33da02aec5fd.tmp
# 24/03/14 09:33:07 INFO CheckpointFileManager: Renamed temp file file:/app/checkpoint/commits/.0.5219c10f-3b79-4fd8-9185-33da02aec5fd.tmp to file:/app/checkpoint/commits/0
# 24/03/14 09:33:07 INFO MicroBatchExecution: Streaming query made progress: {
#   "id" : "fecb0560-68f2-42df-9c50-32c870e251ce",
#   "runId" : "34e3138d-a1e4-4da7-bddd-a12597b03fd5",
#   "name" : null,
#   "timestamp" : "2024-03-14T09:33:05.771Z",
#   "batchId" : 0,
#   "numInputRows" : 8,
#   "inputRowsPerSecond" : 0.0,
#   "processedRowsPerSecond" : 4.331348132106118,
#   "durationMs" : {
#     "addBatch" : 1670,
#     "commitOffsets" : 21,
#     "getBatch" : 6,
#     "latestOffset" : 61,
#     "queryPlanning" : 54,
#     "triggerExecution" : 1846,
#     "walCommit" : 25
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "KafkaV2[Subscribe[rds_first_topic]]",
#     "startOffset" : null,
#     "endOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "latestOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "numInputRows" : 8,
#     "inputRowsPerSecond" : 0.0,
#     "processedRowsPerSecond" : 4.331348132106118,
#     "metrics" : {
#       "avgOffsetsBehindLatest" : "0.0",
#       "maxOffsetsBehindLatest" : "0",
#       "minOffsetsBehindLatest" : "0"
#     }
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.kafka010.KafkaSourceProvider$KafkaTable@18c2fb23",
#     "numOutputRows" : 8
#   }
# }
# 24/03/14 09:33:07 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 1000 milliseconds, but spent 1869 milliseconds
# 24/03/14 09:33:18 INFO MicroBatchExecution: Streaming query made progress: {
#   "id" : "fecb0560-68f2-42df-9c50-32c870e251ce",
#   "runId" : "34e3138d-a1e4-4da7-bddd-a12597b03fd5",
#   "name" : null,
#   "timestamp" : "2024-03-14T09:33:18.001Z",
#   "batchId" : 1,
#   "numInputRows" : 0,
#   "inputRowsPerSecond" : 0.0,
#   "processedRowsPerSecond" : 0.0,
#   "durationMs" : {
#     "latestOffset" : 9,
#     "triggerExecution" : 9
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "KafkaV2[Subscribe[rds_first_topic]]",
#     "startOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "endOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "latestOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "numInputRows" : 0,
#     "inputRowsPerSecond" : 0.0,
#     "processedRowsPerSecond" : 0.0,
#     "metrics" : {
#       "avgOffsetsBehindLatest" : "0.0",
#       "maxOffsetsBehindLatest" : "0",
#       "minOffsetsBehindLatest" : "0"
#     }
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.kafka010.KafkaSourceProvider$KafkaTable@18c2fb23",
#     "numOutputRows" : 0
#   }
# }
# 24/03/14 09:33:28 INFO MicroBatchExecution: Streaming query made progress: {
#   "id" : "fecb0560-68f2-42df-9c50-32c870e251ce",
#   "runId" : "34e3138d-a1e4-4da7-bddd-a12597b03fd5",
#   "name" : null,
#   "timestamp" : "2024-03-14T09:33:28.002Z",
#   "batchId" : 1,
#   "numInputRows" : 0,
#   "inputRowsPerSecond" : 0.0,
#   "processedRowsPerSecond" : 0.0,
#   "durationMs" : {
#     "latestOffset" : 9,
#     "triggerExecution" : 9
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "KafkaV2[Subscribe[rds_first_topic]]",
#     "startOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "endOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "latestOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "numInputRows" : 0,
#     "inputRowsPerSecond" : 0.0,
#     "processedRowsPerSecond" : 0.0,
#     "metrics" : {
#       "avgOffsetsBehindLatest" : "0.0",
#       "maxOffsetsBehindLatest" : "0",
#       "minOffsetsBehindLatest" : "0"
#     }
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.kafka010.KafkaSourceProvider$KafkaTable@18c2fb23",
#     "numOutputRows" : 0
#   }
# }
# 24/03/14 09:33:39 INFO MicroBatchExecution: Streaming query made progress: {
#   "id" : "fecb0560-68f2-42df-9c50-32c870e251ce",
#   "runId" : "34e3138d-a1e4-4da7-bddd-a12597b03fd5",
#   "name" : null,
#   "timestamp" : "2024-03-14T09:33:39.001Z",
#   "batchId" : 1,
#   "numInputRows" : 0,
#   "inputRowsPerSecond" : 0.0,
#   "processedRowsPerSecond" : 0.0,
#   "durationMs" : {
#     "latestOffset" : 9,
#     "triggerExecution" : 10
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "KafkaV2[Subscribe[rds_first_topic]]",
#     "startOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "endOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "latestOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "numInputRows" : 0,
#     "inputRowsPerSecond" : 0.0,
#     "processedRowsPerSecond" : 0.0,
#     "metrics" : {
#       "avgOffsetsBehindLatest" : "0.0",
#       "maxOffsetsBehindLatest" : "0",
#       "minOffsetsBehindLatest" : "0"
#     }
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.kafka010.KafkaSourceProvider$KafkaTable@18c2fb23",
#     "numOutputRows" : 0
#   }
# }
# 24/03/14 09:33:50 INFO MicroBatchExecution: Streaming query made progress: {
#   "id" : "fecb0560-68f2-42df-9c50-32c870e251ce",
#   "runId" : "34e3138d-a1e4-4da7-bddd-a12597b03fd5",
#   "name" : null,
#   "timestamp" : "2024-03-14T09:33:50.001Z",
#   "batchId" : 1,
#   "numInputRows" : 0,
#   "inputRowsPerSecond" : 0.0,
#   "processedRowsPerSecond" : 0.0,
#   "durationMs" : {
#     "latestOffset" : 10,
#     "triggerExecution" : 11
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "KafkaV2[Subscribe[rds_first_topic]]",
#     "startOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "endOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "latestOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "numInputRows" : 0,
#     "inputRowsPerSecond" : 0.0,
#     "processedRowsPerSecond" : 0.0,
#     "metrics" : {
#       "avgOffsetsBehindLatest" : "0.0",
#       "maxOffsetsBehindLatest" : "0",
#       "minOffsetsBehindLatest" : "0"
#     }
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.kafka010.KafkaSourceProvider$KafkaTable@18c2fb23",
#     "numOutputRows" : 0
#   }
# }
# 24/03/14 09:34:01 INFO MicroBatchExecution: Streaming query made progress: {
#   "id" : "fecb0560-68f2-42df-9c50-32c870e251ce",
#   "runId" : "34e3138d-a1e4-4da7-bddd-a12597b03fd5",
#   "name" : null,
#   "timestamp" : "2024-03-14T09:34:01.001Z",
#   "batchId" : 1,
#   "numInputRows" : 0,
#   "inputRowsPerSecond" : 0.0,
#   "processedRowsPerSecond" : 0.0,
#   "durationMs" : {
#     "latestOffset" : 9,
#     "triggerExecution" : 9
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "KafkaV2[Subscribe[rds_first_topic]]",
#     "startOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "endOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "latestOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "numInputRows" : 0,
#     "inputRowsPerSecond" : 0.0,
#     "processedRowsPerSecond" : 0.0,
#     "metrics" : {
#       "avgOffsetsBehindLatest" : "0.0",
#       "maxOffsetsBehindLatest" : "0",
#       "minOffsetsBehindLatest" : "0"
#     }
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.kafka010.KafkaSourceProvider$KafkaTable@18c2fb23",
#     "numOutputRows" : 0
#   }
# }
# 24/03/14 09:34:11 INFO MicroBatchExecution: Streaming query made progress: {
#   "id" : "fecb0560-68f2-42df-9c50-32c870e251ce",
#   "runId" : "34e3138d-a1e4-4da7-bddd-a12597b03fd5",
#   "name" : null,
#   "timestamp" : "2024-03-14T09:34:11.000Z",
#   "batchId" : 1,
#   "numInputRows" : 0,
#   "inputRowsPerSecond" : 0.0,
#   "processedRowsPerSecond" : 0.0,
#   "durationMs" : {
#     "latestOffset" : 9,
#     "triggerExecution" : 9
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "KafkaV2[Subscribe[rds_first_topic]]",
#     "startOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "endOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "latestOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "numInputRows" : 0,
#     "inputRowsPerSecond" : 0.0,
#     "processedRowsPerSecond" : 0.0,
#     "metrics" : {
#       "avgOffsetsBehindLatest" : "0.0",
#       "maxOffsetsBehindLatest" : "0",
#       "minOffsetsBehindLatest" : "0"
#     }
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.kafka010.KafkaSourceProvider$KafkaTable@18c2fb23",
#     "numOutputRows" : 0
#   }
# }
# 24/03/14 09:34:22 INFO MicroBatchExecution: Streaming query made progress: {
#   "id" : "fecb0560-68f2-42df-9c50-32c870e251ce",
#   "runId" : "34e3138d-a1e4-4da7-bddd-a12597b03fd5",
#   "name" : null,
#   "timestamp" : "2024-03-14T09:34:22.001Z",
#   "batchId" : 1,
#   "numInputRows" : 0,
#   "inputRowsPerSecond" : 0.0,
#   "processedRowsPerSecond" : 0.0,
#   "durationMs" : {
#     "latestOffset" : 8,
#     "triggerExecution" : 8
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "KafkaV2[Subscribe[rds_first_topic]]",
#     "startOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "endOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "latestOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "numInputRows" : 0,
#     "inputRowsPerSecond" : 0.0,
#     "processedRowsPerSecond" : 0.0,
#     "metrics" : {
#       "avgOffsetsBehindLatest" : "0.0",
#       "maxOffsetsBehindLatest" : "0",
#       "minOffsetsBehindLatest" : "0"
#     }
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.kafka010.KafkaSourceProvider$KafkaTable@18c2fb23",
#     "numOutputRows" : 0
#   }
# }
# 24/03/14 09:34:32 INFO MicroBatchExecution: Streaming query made progress: {
#   "id" : "fecb0560-68f2-42df-9c50-32c870e251ce",
#   "runId" : "34e3138d-a1e4-4da7-bddd-a12597b03fd5",
#   "name" : null,
#   "timestamp" : "2024-03-14T09:34:32.001Z",
#   "batchId" : 1,
#   "numInputRows" : 0,
#   "inputRowsPerSecond" : 0.0,
#   "processedRowsPerSecond" : 0.0,
#   "durationMs" : {
#     "latestOffset" : 9,
#     "triggerExecution" : 9
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "KafkaV2[Subscribe[rds_first_topic]]",
#     "startOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "endOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "latestOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "numInputRows" : 0,
#     "inputRowsPerSecond" : 0.0,
#     "processedRowsPerSecond" : 0.0,
#     "metrics" : {
#       "avgOffsetsBehindLatest" : "0.0",
#       "maxOffsetsBehindLatest" : "0",
#       "minOffsetsBehindLatest" : "0"
#     }
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.kafka010.KafkaSourceProvider$KafkaTable@18c2fb23",
#     "numOutputRows" : 0
#   }
# }
# 24/03/14 09:34:43 INFO MicroBatchExecution: Streaming query made progress: {
#   "id" : "fecb0560-68f2-42df-9c50-32c870e251ce",
#   "runId" : "34e3138d-a1e4-4da7-bddd-a12597b03fd5",
#   "name" : null,
#   "timestamp" : "2024-03-14T09:34:43.002Z",
#   "batchId" : 1,
#   "numInputRows" : 0,
#   "inputRowsPerSecond" : 0.0,
#   "processedRowsPerSecond" : 0.0,
#   "durationMs" : {
#     "latestOffset" : 7,
#     "triggerExecution" : 7
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "KafkaV2[Subscribe[rds_first_topic]]",
#     "startOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "endOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "latestOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "numInputRows" : 0,
#     "inputRowsPerSecond" : 0.0,
#     "processedRowsPerSecond" : 0.0,
#     "metrics" : {
#       "avgOffsetsBehindLatest" : "0.0",
#       "maxOffsetsBehindLatest" : "0",
#       "minOffsetsBehindLatest" : "0"
#     }
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.kafka010.KafkaSourceProvider$KafkaTable@18c2fb23",
#     "numOutputRows" : 0
#   }
# }
# 24/03/14 09:34:54 INFO MicroBatchExecution: Streaming query made progress: {
#   "id" : "fecb0560-68f2-42df-9c50-32c870e251ce",
#   "runId" : "34e3138d-a1e4-4da7-bddd-a12597b03fd5",
#   "name" : null,
#   "timestamp" : "2024-03-14T09:34:54.001Z",
#   "batchId" : 1,
#   "numInputRows" : 0,
#   "inputRowsPerSecond" : 0.0,
#   "processedRowsPerSecond" : 0.0,
#   "durationMs" : {
#     "latestOffset" : 5,
#     "triggerExecution" : 6
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "KafkaV2[Subscribe[rds_first_topic]]",
#     "startOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "endOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "latestOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "numInputRows" : 0,
#     "inputRowsPerSecond" : 0.0,
#     "processedRowsPerSecond" : 0.0,
#     "metrics" : {
#       "avgOffsetsBehindLatest" : "0.0",
#       "maxOffsetsBehindLatest" : "0",
#       "minOffsetsBehindLatest" : "0"
#     }
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.kafka010.KafkaSourceProvider$KafkaTable@18c2fb23",
#     "numOutputRows" : 0
#   }
# }
# 24/03/14 09:35:04 INFO MicroBatchExecution: Streaming query made progress: {
#   "id" : "fecb0560-68f2-42df-9c50-32c870e251ce",
#   "runId" : "34e3138d-a1e4-4da7-bddd-a12597b03fd5",
#   "name" : null,
#   "timestamp" : "2024-03-14T09:35:04.002Z",
#   "batchId" : 1,
#   "numInputRows" : 0,
#   "inputRowsPerSecond" : 0.0,
#   "processedRowsPerSecond" : 0.0,
#   "durationMs" : {
#     "latestOffset" : 8,
#     "triggerExecution" : 8
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "KafkaV2[Subscribe[rds_first_topic]]",
#     "startOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "endOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "latestOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "numInputRows" : 0,
#     "inputRowsPerSecond" : 0.0,
#     "processedRowsPerSecond" : 0.0,
#     "metrics" : {
#       "avgOffsetsBehindLatest" : "0.0",
#       "maxOffsetsBehindLatest" : "0",
#       "minOffsetsBehindLatest" : "0"
#     }
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.kafka010.KafkaSourceProvider$KafkaTable@18c2fb23",
#     "numOutputRows" : 0
#   }
# }
# 24/03/14 09:35:15 INFO MicroBatchExecution: Streaming query made progress: {
#   "id" : "fecb0560-68f2-42df-9c50-32c870e251ce",
#   "runId" : "34e3138d-a1e4-4da7-bddd-a12597b03fd5",
#   "name" : null,
#   "timestamp" : "2024-03-14T09:35:15.001Z",
#   "batchId" : 1,
#   "numInputRows" : 0,
#   "inputRowsPerSecond" : 0.0,
#   "processedRowsPerSecond" : 0.0,
#   "durationMs" : {
#     "latestOffset" : 7,
#     "triggerExecution" : 7
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "KafkaV2[Subscribe[rds_first_topic]]",
#     "startOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "endOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "latestOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "numInputRows" : 0,
#     "inputRowsPerSecond" : 0.0,
#     "processedRowsPerSecond" : 0.0,
#     "metrics" : {
#       "avgOffsetsBehindLatest" : "0.0",
#       "maxOffsetsBehindLatest" : "0",
#       "minOffsetsBehindLatest" : "0"
#     }
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.kafka010.KafkaSourceProvider$KafkaTable@18c2fb23",
#     "numOutputRows" : 0
#   }
# }
# 24/03/14 09:35:25 INFO MicroBatchExecution: Streaming query made progress: {
#   "id" : "fecb0560-68f2-42df-9c50-32c870e251ce",
#   "runId" : "34e3138d-a1e4-4da7-bddd-a12597b03fd5",
#   "name" : null,
#   "timestamp" : "2024-03-14T09:35:25.001Z",
#   "batchId" : 1,
#   "numInputRows" : 0,
#   "inputRowsPerSecond" : 0.0,
#   "processedRowsPerSecond" : 0.0,
#   "durationMs" : {
#     "latestOffset" : 8,
#     "triggerExecution" : 8
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "KafkaV2[Subscribe[rds_first_topic]]",
#     "startOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "endOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "latestOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "numInputRows" : 0,
#     "inputRowsPerSecond" : 0.0,
#     "processedRowsPerSecond" : 0.0,
#     "metrics" : {
#       "avgOffsetsBehindLatest" : "0.0",
#       "maxOffsetsBehindLatest" : "0",
#       "minOffsetsBehindLatest" : "0"
#     }
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.kafka010.KafkaSourceProvider$KafkaTable@18c2fb23",
#     "numOutputRows" : 0
#   }
# }
# 24/03/14 09:35:35 INFO MicroBatchExecution: Streaming query made progress: {
#   "id" : "fecb0560-68f2-42df-9c50-32c870e251ce",
#   "runId" : "34e3138d-a1e4-4da7-bddd-a12597b03fd5",
#   "name" : null,
#   "timestamp" : "2024-03-14T09:35:35.001Z",
#   "batchId" : 1,
#   "numInputRows" : 0,
#   "inputRowsPerSecond" : 0.0,
#   "processedRowsPerSecond" : 0.0,
#   "durationMs" : {
#     "latestOffset" : 7,
#     "triggerExecution" : 7
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "KafkaV2[Subscribe[rds_first_topic]]",
#     "startOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "endOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "latestOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "numInputRows" : 0,
#     "inputRowsPerSecond" : 0.0,
#     "processedRowsPerSecond" : 0.0,
#     "metrics" : {
#       "avgOffsetsBehindLatest" : "0.0",
#       "maxOffsetsBehindLatest" : "0",
#       "minOffsetsBehindLatest" : "0"
#     }
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.kafka010.KafkaSourceProvider$KafkaTable@18c2fb23",
#     "numOutputRows" : 0
#   }
# }
# 24/03/14 09:35:46 INFO MicroBatchExecution: Streaming query made progress: {
#   "id" : "fecb0560-68f2-42df-9c50-32c870e251ce",
#   "runId" : "34e3138d-a1e4-4da7-bddd-a12597b03fd5",
#   "name" : null,
#   "timestamp" : "2024-03-14T09:35:46.002Z",
#   "batchId" : 1,
#   "numInputRows" : 0,
#   "inputRowsPerSecond" : 0.0,
#   "processedRowsPerSecond" : 0.0,
#   "durationMs" : {
#     "latestOffset" : 7,
#     "triggerExecution" : 7
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "KafkaV2[Subscribe[rds_first_topic]]",
#     "startOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "endOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "latestOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "numInputRows" : 0,
#     "inputRowsPerSecond" : 0.0,
#     "processedRowsPerSecond" : 0.0,
#     "metrics" : {
#       "avgOffsetsBehindLatest" : "0.0",
#       "maxOffsetsBehindLatest" : "0",
#       "minOffsetsBehindLatest" : "0"
#     }
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.kafka010.KafkaSourceProvider$KafkaTable@18c2fb23",
#     "numOutputRows" : 0
#   }
# }
# 24/03/14 09:35:57 INFO MicroBatchExecution: Streaming query made progress: {
#   "id" : "fecb0560-68f2-42df-9c50-32c870e251ce",
#   "runId" : "34e3138d-a1e4-4da7-bddd-a12597b03fd5",
#   "name" : null,
#   "timestamp" : "2024-03-14T09:35:57.001Z",
#   "batchId" : 1,
#   "numInputRows" : 0,
#   "inputRowsPerSecond" : 0.0,
#   "processedRowsPerSecond" : 0.0,
#   "durationMs" : {
#     "latestOffset" : 7,
#     "triggerExecution" : 7
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "KafkaV2[Subscribe[rds_first_topic]]",
#     "startOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "endOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "latestOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "numInputRows" : 0,
#     "inputRowsPerSecond" : 0.0,
#     "processedRowsPerSecond" : 0.0,
#     "metrics" : {
#       "avgOffsetsBehindLatest" : "0.0",
#       "maxOffsetsBehindLatest" : "0",
#       "minOffsetsBehindLatest" : "0"
#     }
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.kafka010.KafkaSourceProvider$KafkaTable@18c2fb23",
#     "numOutputRows" : 0
#   }
# }
# 24/03/14 09:36:07 INFO MicroBatchExecution: Streaming query made progress: {
#   "id" : "fecb0560-68f2-42df-9c50-32c870e251ce",
#   "runId" : "34e3138d-a1e4-4da7-bddd-a12597b03fd5",
#   "name" : null,
#   "timestamp" : "2024-03-14T09:36:07.001Z",
#   "batchId" : 1,
#   "numInputRows" : 0,
#   "inputRowsPerSecond" : 0.0,
#   "processedRowsPerSecond" : 0.0,
#   "durationMs" : {
#     "latestOffset" : 6,
#     "triggerExecution" : 8
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "KafkaV2[Subscribe[rds_first_topic]]",
#     "startOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "endOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "latestOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "numInputRows" : 0,
#     "inputRowsPerSecond" : 0.0,
#     "processedRowsPerSecond" : 0.0,
#     "metrics" : {
#       "avgOffsetsBehindLatest" : "0.0",
#       "maxOffsetsBehindLatest" : "0",
#       "minOffsetsBehindLatest" : "0"
#     }
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.kafka010.KafkaSourceProvider$KafkaTable@18c2fb23",
#     "numOutputRows" : 0
#   }
# }
# 24/03/14 09:36:18 INFO MicroBatchExecution: Streaming query made progress: {
#   "id" : "fecb0560-68f2-42df-9c50-32c870e251ce",
#   "runId" : "34e3138d-a1e4-4da7-bddd-a12597b03fd5",
#   "name" : null,
#   "timestamp" : "2024-03-14T09:36:18.001Z",
#   "batchId" : 1,
#   "numInputRows" : 0,
#   "inputRowsPerSecond" : 0.0,
#   "processedRowsPerSecond" : 0.0,
#   "durationMs" : {
#     "latestOffset" : 7,
#     "triggerExecution" : 7
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "KafkaV2[Subscribe[rds_first_topic]]",
#     "startOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "endOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "latestOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "numInputRows" : 0,
#     "inputRowsPerSecond" : 0.0,
#     "processedRowsPerSecond" : 0.0,
#     "metrics" : {
#       "avgOffsetsBehindLatest" : "0.0",
#       "maxOffsetsBehindLatest" : "0",
#       "minOffsetsBehindLatest" : "0"
#     }
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.kafka010.KafkaSourceProvider$KafkaTable@18c2fb23",
#     "numOutputRows" : 0
#   }
# }
# 24/03/14 09:36:28 INFO MicroBatchExecution: Streaming query made progress: {
#   "id" : "fecb0560-68f2-42df-9c50-32c870e251ce",
#   "runId" : "34e3138d-a1e4-4da7-bddd-a12597b03fd5",
#   "name" : null,
#   "timestamp" : "2024-03-14T09:36:28.001Z",
#   "batchId" : 1,
#   "numInputRows" : 0,
#   "inputRowsPerSecond" : 0.0,
#   "processedRowsPerSecond" : 0.0,
#   "durationMs" : {
#     "latestOffset" : 7,
#     "triggerExecution" : 7
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "KafkaV2[Subscribe[rds_first_topic]]",
#     "startOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "endOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "latestOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "numInputRows" : 0,
#     "inputRowsPerSecond" : 0.0,
#     "processedRowsPerSecond" : 0.0,
#     "metrics" : {
#       "avgOffsetsBehindLatest" : "0.0",
#       "maxOffsetsBehindLatest" : "0",
#       "minOffsetsBehindLatest" : "0"
#     }
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.kafka010.KafkaSourceProvider$KafkaTable@18c2fb23",
#     "numOutputRows" : 0
#   }
# }
# 24/03/14 09:36:38 INFO MicroBatchExecution: Streaming query made progress: {
#   "id" : "fecb0560-68f2-42df-9c50-32c870e251ce",
#   "runId" : "34e3138d-a1e4-4da7-bddd-a12597b03fd5",
#   "name" : null,
#   "timestamp" : "2024-03-14T09:36:38.001Z",
#   "batchId" : 1,
#   "numInputRows" : 0,
#   "inputRowsPerSecond" : 0.0,
#   "processedRowsPerSecond" : 0.0,
#   "durationMs" : {
#     "latestOffset" : 6,
#     "triggerExecution" : 7
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "KafkaV2[Subscribe[rds_first_topic]]",
#     "startOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "endOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "latestOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "numInputRows" : 0,
#     "inputRowsPerSecond" : 0.0,
#     "processedRowsPerSecond" : 0.0,
#     "metrics" : {
#       "avgOffsetsBehindLatest" : "0.0",
#       "maxOffsetsBehindLatest" : "0",
#       "minOffsetsBehindLatest" : "0"
#     }
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.kafka010.KafkaSourceProvider$KafkaTable@18c2fb23",
#     "numOutputRows" : 0
#   }
# }
# 24/03/14 09:36:49 INFO MicroBatchExecution: Streaming query made progress: {
#   "id" : "fecb0560-68f2-42df-9c50-32c870e251ce",
#   "runId" : "34e3138d-a1e4-4da7-bddd-a12597b03fd5",
#   "name" : null,
#   "timestamp" : "2024-03-14T09:36:49.002Z",
#   "batchId" : 1,
#   "numInputRows" : 0,
#   "inputRowsPerSecond" : 0.0,
#   "processedRowsPerSecond" : 0.0,
#   "durationMs" : {
#     "latestOffset" : 6,
#     "triggerExecution" : 6
#   },
#   "stateOperators" : [ ],
#   "sources" : [ {
#     "description" : "KafkaV2[Subscribe[rds_first_topic]]",
#     "startOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "endOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "latestOffset" : {
#       "rds_first_topic" : {
#         "0" : 8
#       }
#     },
#     "numInputRows" : 0,
#     "inputRowsPerSecond" : 0.0,
#     "processedRowsPerSecond" : 0.0,
#     "metrics" : {
#       "avgOffsetsBehindLatest" : "0.0",
#       "maxOffsetsBehindLatest" : "0",
#       "minOffsetsBehindLatest" : "0"
#     }
#   } ],
#   "sink" : {
#     "description" : "org.apache.spark.sql.kafka010.KafkaSourceProvider$KafkaTable@18c2fb23",
#     "numOutputRows" : 0
#   }
# }
